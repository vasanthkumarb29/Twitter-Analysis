# %% [markdown]
# # **Stock Market Analysis of Twitter Inc from 2013 to 2022**

# %% [markdown]
# **About Dataset**

# %% [markdown]
# Stock Market Analysis of Twitter Inc from it's Founding / Listing (when Twitter start its selling the stock prices officilly) Years which is 2013 to 2022.

# %% [markdown]
# Importing a modules

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# importing a data set

# %%
stock_market_df=pd.read_csv('D:/vasanth/sem2/python/Twitter/TWTR.csv')

# %%
stock_market_df
# Out:
#             Date       Open       High        Low      Close  Adj Close  \
# 0     2013-12-09  45.590000  49.840000  45.020000  49.139999  49.139999
# 1     2013-12-10  48.900002  52.580002  48.700001  51.990002  51.990002
# 2     2013-12-11  52.400002  53.869999  51.000000  52.340000  52.340000
# 3     2013-12-12  52.200001  55.869999  50.689999  55.330002  55.330002
# 4     2013-12-13  56.200001  59.410000  55.450001  59.000000  59.000000
# ...          ...        ...        ...        ...        ...        ...
# 2233  2022-10-21  50.000000  50.750000  49.549999  49.889999  49.889999
# 2234  2022-10-24  50.709999  51.860001  50.520000  51.520000  51.520000
# 2235  2022-10-25  52.415001  53.180000  52.200001  52.779999  52.779999
# 2236  2022-10-26  52.950001  53.500000  52.770000  53.349998  53.349998
# 2237  2022-10-27  53.910000  54.000000  53.700001  53.700001  53.700001
#
#          Volume
# 0      17366614
# 1      25792002
# 2      26631535
# 3      23446870
# ...

# %% [markdown]
# **Description of Columns**

# %% [markdown]
# Date - Date of Listing (YYYY-MM-DD)<br>
# Open - Price when the market opens<br>
# High - Highest recorded price for the day<br>
# Low - Lowest recorded price for the day<br>
# Close - Price when the market closes<br>
# Adj Close-  Modified closing price based on corporate actions<br>
# Volume - Amount of stocks sold in a day

# %% [markdown]
# **Information about the dataset**

# %%
stock_market_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2238 entries, 0 to 2237
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       2238 non-null   object
#  1   Open       2238 non-null   float64
#  2   High       2238 non-null   float64
#  3   Low        2238 non-null   float64
#  4   Close      2238 non-null   float64
#  5   Adj Close  2238 non-null   float64
#  6   Volume     2238 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 122.5+ KB

# %%
stock_market_df.shape
# Out:
# (2238, 7)

# %%
print(stock_market_df.head())
# Out:
#          Date       Open       High        Low      Close  Adj Close    Volume
# 0  2013-12-09  45.590000  49.840000  45.020000  49.139999  49.139999  17366614
# 1  2013-12-10  48.900002  52.580002  48.700001  51.990002  51.990002  25792002
# 2  2013-12-11  52.400002  53.869999  51.000000  52.340000  52.340000  26631535
# 3  2013-12-12  52.200001  55.869999  50.689999  55.330002  55.330002  23446870
# 4  2013-12-13  56.200001  59.410000  55.450001  59.000000  59.000000  38979567

# %%
print(stock_market_df.tail())
# Out:
#             Date       Open       High        Low      Close  Adj Close  \
# 2233  2022-10-21  50.000000  50.750000  49.549999  49.889999  49.889999
# 2234  2022-10-24  50.709999  51.860001  50.520000  51.520000  51.520000
# 2235  2022-10-25  52.415001  53.180000  52.200001  52.779999  52.779999
# 2236  2022-10-26  52.950001  53.500000  52.770000  53.349998  53.349998
# 2237  2022-10-27  53.910000  54.000000  53.700001  53.700001  53.700001
#
#          Volume
# 2233   51209029
# 2234   22987553
# 2235   35077848
# 2236   28064973
# 2237  136345128

# %% [markdown]
# **Data Cleaning**

# %%
print(stock_market_df.duplicated())
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2233    False
# 2234    False
# 2235    False
# 2236    False
# 2237    False
# Length: 2238, dtype: bool

# %%
print(stock_market_df.isnull().sum())
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
print(stock_market_df.isna().sum())
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
stock_market_df.dtypes
# Out:
# Date          object
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Adj Close    float64
# Volume         int64
# dtype: object

# %%
stock_market_df['Date'] = pd.to_datetime(stock_market_df['Date'], format='%Y-%m-%d')

# %% [markdown]
# **Descriptive Statics**

# %%
print(stock_market_df.describe())
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  2238.000000  2238.000000  2238.000000  2238.000000  2238.000000
# mean     35.961396    36.635702    35.285190    35.944794    35.944794
# std      14.170256    14.422235    13.881306    14.141829    14.141829
# min      13.950000    14.220000    13.725000    14.010000    14.010000
# 25%      25.402499    25.970000    24.692501    25.267500    25.267500
# 50%      35.264999    35.970001    34.692501    35.359999    35.359999
# 75%      44.209999    45.000000    43.372500    44.147501    44.147501
# max      78.360001    80.750000    76.050003    77.629997    77.629997
#
#              Volume
# count  2.238000e+03
# mean   2.181679e+07
# std    1.904111e+07
# min    0.000000e+00
# 25%    1.247043e+07
# 50%    1.703495e+07
# 75%    2.429828e+07
# max    2.692131e+08

# %%
print(stock_market_df.min())
# Out:
# Date         2013-12-09 00:00:00
# Open                       13.95
# High                       14.22
# Low                       13.725
# Close                      14.01
# Adj Close                  14.01
# Volume                         0
# dtype: object

# %%
print('Range:', stock_market_df.max() - stock_market_df.min())
# Out:
# Range: Date         3244 days 00:00:00
# Open                  64.410001
# High                      66.53
# Low                   62.325003
# Close                 63.619997
# Adj Close             63.619997
# Volume                269213085
# dtype: object

# %%
print('Skewness:', stock_market_df.skew())
# Out:
# Skewness: Open         0.473873
# High         0.473298
# Low          0.467039
# Close        0.468141
# Adj Close    0.468141
# Volume       5.139253
# dtype: float64
# C:\Users\Vasanth\AppData\Local\Temp\ipykernel_8132\617506878.py:1: FutureWarning: The default value of numeric_only in DataFrame.skew is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   print('Skewness:', stock_market_df.skew())

# %%
print('Kurtosis:', stock_market_df.kurtosis())
# Out:
# Kurtosis: Open         -0.285905
# High         -0.278769
# Low          -0.311425
# Close        -0.300454
# Adj Close    -0.300454
# Volume       41.875321
# dtype: float64
# C:\Users\Vasanth\AppData\Local\Temp\ipykernel_8132\594351293.py:1: FutureWarning: The default value of numeric_only in DataFrame.kurt is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   print('Kurtosis:', stock_market_df.kurtosis())

# %%
print(stock_market_df.corr())
# Out:
#                Open      High       Low     Close  Adj Close    Volume
# Open       1.000000  0.998900  0.998620  0.997478   0.997478 -0.014936
# High       0.998900  1.000000  0.998325  0.998782   0.998782 -0.001399
# Low        0.998620  0.998325  1.000000  0.998910   0.998910 -0.030668
# Close      0.997478  0.998782  0.998910  1.000000   1.000000 -0.018298
# Adj Close  0.997478  0.998782  0.998910  1.000000   1.000000 -0.018298
# Volume    -0.014936 -0.001399 -0.030668 -0.018298  -0.018298  1.000000
# C:\Users\Vasanth\AppData\Local\Temp\ipykernel_8132\3244732769.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   print(stock_market_df.corr())

# %% [markdown]
# **Series plot** :Since the dataset contains time-series data, we can create a line plot of the 'Close' column against the 'Date' column. This will give us an idea of how the closing prices have changed over time.

# %%
plt.figure(figsize=(10,5))
plt.plot(stock_market_df['Date'], stock_market_df['Close'])
plt.xlabel('Date')
plt.ylabel('Closing Price')
plt.title('Closing Price of Twitter Inc over Time')
plt.show()

# %% [markdown]
#  **Correlation heatmap:** We can create a correlation heatmap to see the correlation between different numeric columns in the dataset.

# %%
sns.heatmap(stock_market_df.corr(), cmap='coolwarm', annot=True)
plt.title('Correlation Matrix')
plt.show()
# Out:
# C:\Users\Vasanth\AppData\Local\Temp\ipykernel_8132\2426413382.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(stock_market_df.corr(), cmap='coolwarm', annot=True)

# %% [markdown]
#  **Scatter plot:** We can create a scatter plot of the 'High' column against the 'Low' column to see the relationship between the highest and lowest recorded price for the day.

# %%
colors = np.random.rand(2238)

plt.scatter(stock_market_df['Date'], stock_market_df['Open'],c=colors , alpha=0.5)
plt.title('Opening price of Twitter Inc')
plt.xlabel('Date')
plt.ylabel('Open')
plt.show()

# %% [markdown]
# **Bar plot:** A bar plot is a useful visualization for showing the relationship between categorical and numerical data

# %%
stock_market_df['Year'] = pd.DatetimeIndex(stock_market_df['Date']).year
df_grouped = stock_market_df.groupby('Year')['Close'].mean()

# %%
plt.bar(df_grouped.index, df_grouped.values)
plt.xlabel('Year')
plt.ylabel('Average Closing Price')
plt.title('Average Closing Price by Year')
plt.show()

# %% [markdown]
#  **Violin plot:** We can create a violin plot of the 'Adj Close' column to see the distribution of the modified closing price based on corporate actions.

# %%
sns.violinplot(x=stock_market_df['Adj Close'])
plt.xlabel('Adj Close')
plt.title('Violin Plot of Adj Close')
plt.show()

# %% [markdown]
# **Histograms:** We can create histograms of all the numeric columns in the dataset using a for loop.

# %%
numeric_cols = ['Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']


for col in numeric_cols:
    plt.hist(stock_market_df[col],edgecolor='black')
    mean_val = np.mean(stock_market_df[col])
    median_val = np.median(stock_market_df[col])
    plt.axvline(mean_val, color='red', linewidth=1)
    plt.axvline(median_val, color='green',  linewidth=1)
    plt.xlabel(col)
    plt.ylabel('Frequency')
    plt.title('Histogram of '+ col)
    plt.show()
